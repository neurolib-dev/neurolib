# %%
# change into root directory to the project
import os
os.chdir('..')

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from neurolib.utils.parameterSpace import ParameterSpace
from neurolib.optimize.evolution import Evolution

import neurolib.optimize.evolution.evolutionaryUtils as eu
import neurolib.utils.functions as func

import random

def optimize_me(traj):
    global evolution
    ind = evolution.getIndividualFromTraj(traj)
    print("Hello, I am {}".format(ind.id))
    print("You can also call me {}, or simply ({:.2}, {:.2}).".format(ind.params, ind.x, ind.y))
    
    # let's make a circle
    computation_result = abs((ind.x**2 + ind.y**2) - 1)
    # DEAP wants a tuple as fitness, ALWAYS!
    fitness_tuple = (computation_result ,)
    
    # we also require a dictionary with at least a single result for storing the results in the hdf
    result_dict = {"result" : [computation_result]}
    
    return fitness_tuple, result_dict

    
pars = ParameterSpace(['x', 'y'], [[-5.0, 5.0], [-5.0, 5.0]])
evolution = Evolution(optimize_me, pars, weightList = [-1.0], POP_INIT_SIZE=200, POP_SIZE = 50, NGEN=20)
evolution.run(verbose = False)
# Out:
# /Users/caglar/anaconda/lib/python3.7/site-packages/deap/tools/_hypervolume/pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)
# /Users/caglar/anaconda/lib/python3.7/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /Users/caglar/anaconda/lib/python3.7/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# INFO:root:Storing data to: ./data/hdf/evolution.hdf
# INFO:root:Trajectory Name: results-2020-01-31-18H-35M-12S
# INFO:root:Number of cores: 8
# DEBUG:pypet.trajectory.Trajectory:Added wildcard function `('$', 'crun')`.
# DEBUG:pypet.trajectory.Trajectory:Added wildcard function `('$set', 'crunset')`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `./data/hdf/evolution.hdf`.
# MainProcess pypet.environment.Environment INFO     Environment initialized.
# MainProcess root INFO     Evaluating initial population of size 200 ...
# MainProcess pypet.trajectory.Trajectory INFO     Your trajectory has not been explored, yet. I will call `f_explore` instead.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-01-31-18H-35M-12S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished   0/200 runs [                    ]  0.0%
# Hello, I am 0
# You can also call me OrderedDict([('x', 1.2493205551414013), ('y', 1.1746287502502115)]), or simply (1.2, 1.2).
# Hello, I am 1
# Hello, I am 2
# You can also call me OrderedDict([('x', 4.75735652850684), ('y', -0.7608698019924294)]), or simply (4.8, -0.76).
# You can also call me OrderedDict([('x', 1.2115678500880556), ('y', -0.6144385578404643)]), or simply (1.2, -0.61).
# Hello, I am 3
# Hello, I am 4
# You can also call me OrderedDict([('x', 3.5954788894652054), ('y', 2.857043423647447)]), or simply (3.6, 2.9).
# You can also call me OrderedDict([('x', 2.107749812037576), ('y', -3.7529208927987865)]), or simply (2.1, -3.8).
# Hello, I am 5
# You can also call me OrderedDict([('x', -3.1762834727652733), ('y', 2.4673868178168483)]), or simply (-3.2, 2.5).
# Hello, I am 6
# You can also call me OrderedDict([('x', -0.9954173200938161), ('y', 2.075546655128994)]), or simply (-1.0, 2.1).
# Hello, I am 7
# You can also call me OrderedDict([('x', 1.55925254568535), ('y', -0.5966010927823318)]), or simply (1.6, -0.6).
# Hello, I am 8
# Hello, I am 9
# You can also call me OrderedDict([('x', -4.343341573256556), ('y', -4.01711261215305)]), or simply (-4.3, -4.0).
# Hello, I am 10
# You can also call me OrderedDict([('x', -4.340038558016987), ('y', -3.7662121829793174)]), or simply (-4.3, -3.8).
# Hello, I am 11
# Hello, I am 12
# You can also call me OrderedDict([('x', -3.6710692239731557), ('y', -1.7194890403999397)]), or simply (-3.7, -1.7).
# You can also call me OrderedDict([('x', 0.36928073484714385), ('y', -1.1740630496069593)]), or simply (0.37, -1.2).
# You can also call me OrderedDict([('x', 4.641720480573078), ('y', 3.126889245393089)]), or simply (4.6, 3.1).
# MainProcess pypet INFO     PROGRESS: Finished  10/200 runs [=                   ]  5.0%, remaining: 0:00:04
# Hello, I am 14
# Hello, I am 13
# You can also call me OrderedDict([('x', 4.151734218044394), ('y', 4.4903047357957675)]), or simply (4.2, 4.5).
# Hello, I am 15
# You can also call me OrderedDict([('x', 2.7251564261397156), ('y', -4.427685820321346)]), or simply (2.7, -4.4).
# You can also call me OrderedDict([('x', -0.6184493657040635), ('y', 4.702936322475926)]), or simply (-0.62, 4.7).
# Hello, I am 16
# You can also call me OrderedDict([('x', -2.144655914365421), ('y', -0.08100789623652283)]), or simply (-2.1, -0.081).
# Hello, I am 17
# You can also call me OrderedDict([('x', 4.570986378209831), ('y', -1.441827661807733)]), or simply (4.6, -1.4).
# Hello, I am 18
# You can also call me OrderedDict([('x', 0.07434267825086671), ('y', -1.8741201948005424)]), or simply (0.074, -1.9).
# Hello, I am 19
# You can also call me OrderedDict([('x', 3.4477333948633273), ('y', 0.6118044127976425)]), or simply (3.4, 0.61).
# Hello, I am 20
# You can also call me OrderedDict([('x', 4.340714783034199), ('y', 1.439456453201445)]), or simply (4.3, 1.4).
# MainProcess pypet INFO     PROGRESS: Finished  20/200 runs [==                  ] 10.0%, remaining: 0:00:03
# Hello, I am 21
# Hello, I am 23
# Hello, I am 22
# You can also call me OrderedDict([('x', -2.1519720681620647), ('y', 2.670711328617048)]), or simply (-2.2, 2.7).
# You can also call me OrderedDict([('x', 1.7198180819109439), ('y', 0.9154031327798373)]), or simply (1.7, 0.92).
# You can also call me OrderedDict([('x', -3.9777225523590443), ('y', 3.8273358329942155)]), or simply (-4.0, 3.8).
# Hello, I am 24
# You can also call me OrderedDict([('x', -2.561792721634104), ('y', 4.760218636970752)]), or simply (-2.6, 4.8).
# Hello, I am 25
# You can also call me OrderedDict([('x', -0.039807401390676844), ('y', -4.765280900656565)]), or simply (-0.04, -4.8).
# Hello, I am 26
# Hello, I am 27
# You can also call me OrderedDict([('x', -2.139400254424583), ('y', -3.245043998724971)]), or simply (-2.1, -3.2).
# You can also call me OrderedDict([('x', -3.60716445975633), ('y', -3.3722825576366464)]), or simply (-3.6, -3.4).
# Hello, I am 28
# Hello, I am 29
# You can also call me OrderedDict([('x', -2.0127302473412003), ('y', -4.015442829038804)]), or simply (-2.0, -4.0).
# You can also call me OrderedDict([('x', -0.6041279788122402), ('y', -4.58343025824702)]), or simply (-0.6, -4.6).
# Hello, I am 30
# You can also call me OrderedDict([('x', -2.1745181479894615), ('y', 4.254911522887694)]), or simply (-2.2, 4.3).
# MainProcess pypet INFO     PROGRESS: Finished  30/200 runs [===                 ] 15.0%, remaining: 0:00:02
# Hello, I am 31
# You can also call me OrderedDict([('x', 2.7156645565605464), ('y', -2.971716960460278)]), or simply (2.7, -3.0).
# Hello, I am 32
# You can also call me OrderedDict([('x', 1.747777034058009), ('y', 3.0672755025167238)]), or simply (1.7, 3.1).
# Hello, I am 33
# You can also call me OrderedDict([('x', -1.7581137072795272), ('y', 3.063731255026381)]), or simply (-1.8, 3.1).
# Hello, I am 34
# Hello, I am 35
# You can also call me OrderedDict([('x', -2.896679659585705), ('y', 3.394552288943432)]), or simply (-2.9, 3.4).
# You can also call me OrderedDict([('x', -3.680170207299592), ('y', -1.0798657535122036)]), or simply (-3.7, -1.1).
# Hello, I am 36
# You can also call me OrderedDict([('x', -3.369099088182974), ('y', 4.537648161770528)]), or simply (-3.4, 4.5).
# Hello, I am 37
# You can also call me OrderedDict([('x', 3.508672431937068), ('y', -1.3581314101228847)]), or simply (3.5, -1.4).
# Hello, I am 38
# You can also call me OrderedDict([('x', 1.3957901634396297), ('y', -0.27521646504579067)]), or simply (1.4, -0.28).
# Hello, I am 39
# You can also call me OrderedDict([('x', -0.9670534146370073), ('y', -1.5970014116389821)]), or simply (-0.97, -1.6).
# MainProcess pypet INFO     PROGRESS: Finished  40/200 runs [====                ] 20.0%, remaining: 0:00:02
# Hello, I am 40
# You can also call me OrderedDict([('x', 2.4808140626188973), ('y', 4.367980230731941)]), or simply (2.5, 4.4).
# Hello, I am 41
# You can also call me OrderedDict([('x', 2.183324408483374), ('y', -0.026373130428724245)]), or simply (2.2, -0.026).
# Hello, I am 42
# You can also call me OrderedDict([('x', 4.245251248704111), ('y', -0.017295596735654506)]), or simply (4.2, -0.017).
# Hello, I am 43
# You can also call me OrderedDict([('x', -3.623596257869346), ('y', 4.453308583008205)]), or simply (-3.6, 4.5).
# Hello, I am 44
# You can also call me OrderedDict([('x', -4.519976216824126), ('y', -4.979502155478215)]), or simply (-4.5, -5.0).
# Hello, I am 45
# You can also call me OrderedDict([('x', -1.280197050444647), ('y', 2.720134316634647)]), or simply (-1.3, 2.7).
# Hello, I am 46
# You can also call me OrderedDict([('x', -3.9042660670514575), ('y', -2.7022360710277016)]), or simply (-3.9, -2.7).
# Hello, I am 47
# You can also call me OrderedDict([('x', -0.8930715306054582), ('y', 2.7985455338236944)]), or simply (-0.89, 2.8).
# Hello, I am 48
# You can also call me OrderedDict([('x', 3.2006091681421296), ('y', 1.8507817075081583)]), or simply (3.2, 1.9).
# Hello, I am 49
# You can also call me OrderedDict([('x', -4.279591636225105), ('y', -3.021161508671877)]), or simply (-4.3, -3.0).
# MainProcess pypet INFO     PROGRESS: Finished  50/200 runs [=====               ] 25.0%, remaining: 0:00:02
# Hello, I am 50
# You can also call me OrderedDict([('x', -0.783854029848781), ('y', -2.4529043258536753)]), or simply (-0.78, -2.5).
# Hello, I am 51
# You can also call me OrderedDict([('x', 4.650521019031666), ('y', -3.6702521576971767)]), or simply (4.7, -3.7).
# Hello, I am 52
# Hello, I am 53
# You can also call me OrderedDict([('x', 3.8683132589012654), ('y', -1.6236819333343169)]), or simply (3.9, -1.6).
# Hello, I am 54
# You can also call me OrderedDict([('x', -1.7655415882938117), ('y', -4.027968138373761)]), or simply (-1.8, -4.0).
# You can also call me OrderedDict([('x', 3.3757805636638576), ('y', 2.59709563845429)]), or simply (3.4, 2.6).
# Hello, I am 55
# You can also call me OrderedDict([('x', -2.763464164234372), ('y', -1.8621735374517545)]), or simply (-2.8, -1.9).
# Hello, I am 56
# You can also call me OrderedDict([('x', 0.3029198151364989), ('y', -1.3223067379499809)]), or simply (0.3, -1.3).
# Hello, I am 57
# You can also call me OrderedDict([('x', -0.6849757434435748), ('y', 3.8120346576536797)]), or simply (-0.68, 3.8).
# Hello, I am 58
# You can also call me OrderedDict([('x', 2.4863067636966028), ('y', -2.598918674803844)]), or simply (2.5, -2.6).
# Hello, I am 59
# You can also call me OrderedDict([('x', -4.480626381586506), ('y', -3.5917257657020074)]), or simply (-4.5, -3.6).
# Hello, I am 60
# MainProcess pypet INFO     PROGRESS: Finished  60/200 runs [======              ] 30.0%, remaining: 0:00:02
# You can also call me OrderedDict([('x', 0.33735150103984424), ('y', 3.0592231933734535)]), or simply (0.34, 3.1).
# Hello, I am 61
# You can also call me OrderedDict([('x', -0.5804583061826705), ('y', 4.1410521126995015)]), or simply (-0.58, 4.1).
# Hello, I am 62
# You can also call me OrderedDict([('x', -4.658297983098814), ('y', -4.668056654915738)]), or simply (-4.7, -4.7).
# Hello, I am 63
# You can also call me OrderedDict([('x', -3.167658897585798), ('y', 1.53190173773213)]), or simply (-3.2, 1.5).
# Hello, I am 65
# You can also call me OrderedDict([('x', 0.4280205879257224), ('y', 1.1219294692428452)]), or simply (0.43, 1.1).
# Hello, I am 64
# You can also call me OrderedDict([('x', -0.023587545223859863), ('y', 1.538579802151406)]), or simply (-0.024, 1.5).
# Hello, I am 66
# You can also call me OrderedDict([('x', -2.5367320252896364), ('y', -0.8920070233546671)]), or simply (-2.5, -0.89).
# Hello, I am 67
# You can also call me OrderedDict([('x', 0.7911571502082069), ('y', 2.7704757910427222)]), or simply (0.79, 2.8).
# Hello, I am 68
# You can also call me OrderedDict([('x', 3.6176487367525745), ('y', 0.8288662450414543)]), or simply (3.6, 0.83).
# Hello, I am 69
# You can also call me OrderedDict([('x', -3.564442013593092), ('y', -1.4546805776872649)]), or simply (-3.6, -1.5).
# MainProcess pypet INFO     PROGRESS: Finished  70/200 runs [=======             ] 35.0%, remaining: 0:00:01
# Hello, I am 70
# Hello, I am 71
# You can also call me OrderedDict([('x', 2.9936110818559225), ('y', -4.737292513406437)]), or simply (3.0, -4.7).
# You can also call me OrderedDict([('x', -2.4707825021371823), ('y', 3.9023573222395402)]), or simply (-2.5, 3.9).
# Hello, I am 72
# You can also call me OrderedDict([('x', -0.6344335583022715), ('y', 3.8042180562265244)]), or simply (-0.63, 3.8).
# Hello, I am 73
# You can also call me OrderedDict([('x', 2.580473423599835), ('y', -1.6268928347523004)]), or simply (2.6, -1.6).
# Hello, I am 74
# You can also call me OrderedDict([('x', -3.5385290991434672), ('y', -3.9713630728492024)]), or simply (-3.5, -4.0).
# Hello, I am 75
# You can also call me OrderedDict([('x', 2.990105385857494), ('y', -1.9822511388380324)]), or simply (3.0, -2.0).
# Hello, I am 76
# You can also call me OrderedDict([('x', 3.3752474621074526), ('y', 4.031275191685571)]), or simply (3.4, 4.0).
# Hello, I am 77
# You can also call me OrderedDict([('x', 1.735436479086374), ('y', 0.37758159826301796)]), or simply (1.7, 0.38).
# Hello, I am 78
# You can also call me OrderedDict([('x', -4.514722489723072), ('y', 0.7303912837871458)]), or simply (-4.5, 0.73).
# Hello, I am 79
# Hello, I am 80
# You can also call me OrderedDict([('x', 2.175786423529469), ('y', -0.13974189543818039)]), or simply (2.2, -0.14).
# You can also call me OrderedDict([('x', -4.91984377481952), ('y', -3.6957892386997218)]), or simply (-4.9, -3.7).
# MainProcess pypet INFO     PROGRESS: Finished  80/200 runs [========            ] 40.0%, remaining: 0:00:01
# Hello, I am 81
# You can also call me OrderedDict([('x', -4.167461082745902), ('y', -3.2741347132682974)]), or simply (-4.2, -3.3).
# Hello, I am 82
# You can also call me OrderedDict([('x', -4.139275249718837), ('y', 3.778301128905227)]), or simply (-4.1, 3.8).
# Hello, I am 83
# You can also call me OrderedDict([('x', -2.8608426782430527), ('y', 4.154216701050258)]), or simply (-2.9, 4.2).
# Hello, I am 84
# You can also call me OrderedDict([('x', -1.1438796350359448), ('y', -1.4733501901849486)]), or simply (-1.1, -1.5).
# Hello, I am 86
# Hello, I am 85
# You can also call me OrderedDict([('x', 4.579340957806513), ('y', -2.217416247302413)]), or simply (4.6, -2.2).
# You can also call me OrderedDict([('x', -3.195567524694064), ('y', -1.9381875555960706)]), or simply (-3.2, -1.9).
# Hello, I am 87
# You can also call me OrderedDict([('x', -2.9290906851807286), ('y', -3.7030807432496617)]), or simply (-2.9, -3.7).
# Hello, I am 88
# You can also call me OrderedDict([('x', 1.4665549685638233), ('y', 4.027964061602233)]), or simply (1.5, 4.0).
# Hello, I am 89
# You can also call me OrderedDict([('x', 3.3593247602943936), ('y', 2.681166085323012)]), or simply (3.4, 2.7).
# MainProcess pypet INFO     PROGRESS: Finished  90/200 runs [=========           ] 45.0%, remaining: 0:00:01
# Hello, I am 90
# You can also call me OrderedDict([('x', 2.876246007730958), ('y', 0.3424568985349232)]), or simply (2.9, 0.34).
# Hello, I am 91
# You can also call me OrderedDict([('x', 0.8481517998725998), ('y', 1.9799499049664124)]), or simply (0.85, 2.0).
# Hello, I am 92
# You can also call me OrderedDict([('x', -1.5852733844997422), ('y', 2.073073460639331)]), or simply (-1.6, 2.1).
# Hello, I am 93
# Hello, I am 94
# You can also call me OrderedDict([('x', 2.456840187980154), ('y', -2.196363795606151)]), or simply (2.5, -2.2).
# You can also call me OrderedDict([('x', 4.471990351522473), ('y', -2.859484745823011)]), or simply (4.5, -2.9).
# Hello, I am 95
# You can also call me OrderedDict([('x', -3.2338246967702267), ('y', 2.5314650751337195)]), or simply (-3.2, 2.5).
# Hello, I am 96
# You can also call me OrderedDict([('x', 4.650362612865072), ('y', -2.7043373124212833)]), or simply (4.7, -2.7).
# Hello, I am 97
# You can also call me OrderedDict([('x', -4.314370171383054), ('y', -2.8564088909079963)]), or simply (-4.3, -2.9).
# Hello, I am 98
# You can also call me OrderedDict([('x', -2.821157523511715), ('y', 1.4830719283284477)]), or simply (-2.8, 1.5).
# Hello, I am 99
# You can also call me OrderedDict([('x', -1.192075493843511), ('y', 0.5805917124525886)]), or simply (-1.2, 0.58).
# MainProcess pypet INFO     PROGRESS: Finished 100/200 runs [==========          ] 50.0%, remaining: 0:00:01
# Hello, I am 100
# You can also call me OrderedDict([('x', -3.2976690031567713), ('y', 1.5731643636163533)]), or simply (-3.3, 1.6).
# Hello, I am 101
# You can also call me OrderedDict([('x', -1.5797483912129628), ('y', -1.3963477447938488)]), or simply (-1.6, -1.4).
# Hello, I am 102
# You can also call me OrderedDict([('x', -4.9104189494088155), ('y', 0.22693117622763825)]), or simply (-4.9, 0.23).
# Hello, I am 103
# You can also call me OrderedDict([('x', 1.0281251422318949), ('y', -4.001775417010158)]), or simply (1.0, -4.0).
# Hello, I am 104
# You can also call me OrderedDict([('x', 0.650700361456888), ('y', 2.4560812559286855)]), or simply (0.65, 2.5).
# Hello, I am 105
# You can also call me OrderedDict([('x', -4.915711284086559), ('y', 4.133875854108361)]), or simply (-4.9, 4.1).
# Hello, I am 106
# You can also call me OrderedDict([('x', -2.1355351685321935), ('y', -1.6767801512898806)]), or simply (-2.1, -1.7).
# Hello, I am 107
# You can also call me OrderedDict([('x', 0.13007559237002386), ('y', -3.112035988374582)]), or simply (0.13, -3.1).
# Hello, I am 108
# You can also call me OrderedDict([('x', -3.4575651051877534), ('y', 3.724883881481457)]), or simply (-3.5, 3.7).
# Hello, I am 109
# You can also call me OrderedDict([('x', 0.8250634585132408), ('y', 3.570809869806517)]), or simply (0.83, 3.6).
# MainProcess pypet INFO     PROGRESS: Finished 110/200 runs [===========         ] 55.0%, remaining: 0:00:01
# Hello, I am 110
# You can also call me OrderedDict([('x', 0.048554356183054814), ('y', 1.1249531979093872)]), or simply (0.049, 1.1).
# Hello, I am 111
# You can also call me OrderedDict([('x', -2.974702531667708), ('y', 3.1675027096677244)]), or simply (-3.0, 3.2).
# Hello, I am 112
# You can also call me OrderedDict([('x', 3.002591990908561), ('y', -1.7311377831682115)]), or simply (3.0, -1.7).
# Hello, I am 113
# You can also call me OrderedDict([('x', -3.838618992793299), ('y', 0.6587472135487076)]), or simply (-3.8, 0.66).
# Hello, I am 114
# You can also call me OrderedDict([('x', -4.91048233585058), ('y', -2.708157039008021)]), or simply (-4.9, -2.7).
# Hello, I am 115
# You can also call me OrderedDict([('x', -2.0954460886034134), ('y', -2.902135043029941)]), or simply (-2.1, -2.9).
# Hello, I am 116
# Hello, I am 117
# You can also call me OrderedDict([('x', 2.0241589943692535), ('y', 1.20474017471948)]), or simply (2.0, 1.2).
# You can also call me OrderedDict([('x', -2.7315482961828086), ('y', -0.8367495910090925)]), or simply (-2.7, -0.84).
# Hello, I am 118
# You can also call me OrderedDict([('x', -3.018436922359218), ('y', 2.0323887713499715)]), or simply (-3.0, 2.0).
# Hello, I am 119
# You can also call me OrderedDict([('x', 1.6072210517409777), ('y', 3.031814767353664)]), or simply (1.6, 3.0).
# Hello, I am 120
# You can also call me OrderedDict([('x', 2.821206439298898), ('y', 1.116505936945603)]), or simply (2.8, 1.1).
# Hello, I am 121
# MainProcess pypet INFO     PROGRESS: Finished 120/200 runs [============        ] 60.0%, remaining: 0:00:01
# You can also call me OrderedDict([('x', 2.915458830954252), ('y', -2.42037449123339)]), or simply (2.9, -2.4).
# Hello, I am 122
# You can also call me OrderedDict([('x', -3.3699592737250708), ('y', 0.6138925020190111)]), or simply (-3.4, 0.61).
# Hello, I am 123
# You can also call me OrderedDict([('x', 0.32057579520250634), ('y', 4.059422752051876)]), or simply (0.32, 4.1).
# Hello, I am 124
# You can also call me OrderedDict([('x', 4.745633665786137), ('y', 1.3226123091029613)]), or simply (4.7, 1.3).
# Hello, I am 126
# You can also call me OrderedDict([('x', -2.2092286206431346), ('y', -2.2287530609725414)]), or simply (-2.2, -2.2).
# Hello, I am 125
# You can also call me OrderedDict([('x', 1.4320525538868534), ('y', 1.67081546642871)]), or simply (1.4, 1.7).
# Hello, I am 127
# You can also call me OrderedDict([('x', 2.072013086130964), ('y', 2.080043077307171)]), or simply (2.1, 2.1).
# Hello, I am 129
# Hello, I am 128
# You can also call me OrderedDict([('x', 0.45720337923591536), ('y', -2.5816633211726225)]), or simply (0.46, -2.6).
# You can also call me OrderedDict([('x', 0.3122054333639337), ('y', -2.0595988619886887)]), or simply (0.31, -2.1).
# Hello, I am 130
# MainProcess pypet INFO     PROGRESS: Finished 130/200 runs [=============       ] 65.0%, remaining: 0:00:01
# You can also call me OrderedDict([('x', -1.3398009172877465), ('y', -3.855965756636862)]), or simply (-1.3, -3.9).
# Hello, I am 131
# You can also call me OrderedDict([('x', -2.4199439785765833), ('y', 3.651141742678181)]), or simply (-2.4, 3.7).
# Hello, I am 132
# You can also call me OrderedDict([('x', 4.758528222981369), ('y', -3.596442364266901)]), or simply (4.8, -3.6).
# Hello, I am 133
# You can also call me OrderedDict([('x', -2.920698054371056), ('y', -1.1128900801449304)]), or simply (-2.9, -1.1).
# Hello, I am 135
# Hello, I am 134
# You can also call me OrderedDict([('x', 3.285696782883539), ('y', 2.4142914807866074)]), or simply (3.3, 2.4).
# You can also call me OrderedDict([('x', 1.106635813703206), ('y', -2.1887207473608283)]), or simply (1.1, -2.2).
# Hello, I am 136
# You can also call me OrderedDict([('x', -3.292448466118405), ('y', 3.9705946582748233)]), or simply (-3.3, 4.0).
# Hello, I am 137
# You can also call me OrderedDict([('x', 3.4652187216312065), ('y', 3.113646390903721)]), or simply (3.5, 3.1).
# Hello, I am 138
# You can also call me OrderedDict([('x', -3.0175236115458084), ('y', 1.3116195343840467)]), or simply (-3.0, 1.3).
# Hello, I am 139
# You can also call me OrderedDict([('x', -3.6469800638804273), ('y', 4.944605016397022)]), or simply (-3.6, 4.9).
# Hello, I am 140
# You can also call me OrderedDict([('x', -1.9514238609916692), ('y', -1.0818409886328775)]), or simply (-2.0, -1.1).
# MainProcess pypet INFO     PROGRESS: Finished 140/200 runs [==============      ] 70.0%, remaining: 0:00:00
# Hello, I am 141
# You can also call me OrderedDict([('x', -0.41625300955931177), ('y', -3.587833673473212)]), or simply (-0.42, -3.6).
# Hello, I am 142
# You can also call me OrderedDict([('x', 1.2915986487845208), ('y', -1.1846158181398247)]), or simply (1.3, -1.2).
# Hello, I am 144
# Hello, I am 143
# You can also call me OrderedDict([('x', 2.0859665111190466), ('y', -2.856198147956448)]), or simply (2.1, -2.9).
# You can also call me OrderedDict([('x', -1.110715654392794), ('y', -0.04777018473119199)]), or simply (-1.1, -0.048).
# Hello, I am 146
# Hello, I am 145
# You can also call me OrderedDict([('x', 1.9802217882322912), ('y', -2.321451652178933)]), or simply (2.0, -2.3).
# You can also call me OrderedDict([('x', -1.0974090584471585), ('y', 3.3270229634193775)]), or simply (-1.1, 3.3).
# Hello, I am 147
# You can also call me OrderedDict([('x', 2.6513911438144238), ('y', -2.2769038634016203)]), or simply (2.7, -2.3).
# Hello, I am 148
# You can also call me OrderedDict([('x', -1.6315298159083746), ('y', 4.092044420725456)]), or simply (-1.6, 4.1).
# Hello, I am 149
# You can also call me OrderedDict([('x', 0.8310068305732319), ('y', 0.8094872895731573)]), or simply (0.83, 0.81).
# Hello, I am 150
# Hello, I am 151
# You can also call me OrderedDict([('x', -1.0184006938160128), ('y', 0.6332462894461823)]), or simply (-1.0, 0.63).
# You can also call me OrderedDict([('x', -1.7511540976574338), ('y', 2.176070147753377)]), or simply (-1.8, 2.2).
# Hello, I am 152
# MainProcess pypet INFO     PROGRESS: Finished 150/200 runs [===============     ] 75.0%, remaining: 0:00:00
# You can also call me OrderedDict([('x', 1.9130803411573716), ('y', 2.3793213118279315)]), or simply (1.9, 2.4).
# Hello, I am 153
# You can also call me OrderedDict([('x', 3.6741527039504334), ('y', -0.40417917611647525)]), or simply (3.7, -0.4).
# Hello, I am 154
# You can also call me OrderedDict([('x', -4.684853756636631), ('y', -2.07267814323746)]), or simply (-4.7, -2.1).
# Hello, I am 155
# You can also call me OrderedDict([('x', 0.1202876315539303), ('y', -1.2787164407804088)]), or simply (0.12, -1.3).
# Hello, I am 156
# You can also call me OrderedDict([('x', 0.06057245850728421), ('y', 1.3072132556642337)]), or simply (0.061, 1.3).
# Hello, I am 158
# Hello, I am 157
# You can also call me OrderedDict([('x', -1.787506410711468), ('y', 0.8226251906678499)]), or simply (-1.8, 0.82).
# You can also call me OrderedDict([('x', 3.3872023796556014), ('y', -0.5887524594482585)]), or simply (3.4, -0.59).
# Hello, I am 159
# You can also call me OrderedDict([('x', -2.1385403223447375), ('y', -3.369206092416711)]), or simply (-2.1, -3.4).
# Hello, I am 160
# You can also call me OrderedDict([('x', -3.9094852356908882), ('y', 2.5765459778675117)]), or simply (-3.9, 2.6).
# Hello, I am 161
# You can also call me OrderedDict([('x', -2.753665501770265), ('y', -4.291292632349171)]), or simply (-2.8, -4.3).
# MainProcess pypet INFO     PROGRESS: Finished 160/200 runs [================    ] 80.0%, remaining: 0:00:00
# Hello, I am 162
# You can also call me OrderedDict([('x', -0.8849798010182877), ('y', -4.24657231211286)]), or simply (-0.88, -4.2).
# Hello, I am 163
# You can also call me OrderedDict([('x', 1.5432900731827734), ('y', 4.602537576657527)]), or simply (1.5, 4.6).
# Hello, I am 164
# You can also call me OrderedDict([('x', -3.0626130017363353), ('y', 0.625033330379507)]), or simply (-3.1, 0.63).
# Hello, I am 165
# Hello, I am 166
# You can also call me OrderedDict([('x', 3.8112548247150446), ('y', 4.007606038676377)]), or simply (3.8, 4.0).
# You can also call me OrderedDict([('x', 4.091630145906112), ('y', 0.20763968241435204)]), or simply (4.1, 0.21).
# Hello, I am 167
# You can also call me OrderedDict([('x', -0.7382070349397187), ('y', -0.5592225729590563)]), or simply (-0.74, -0.56).
# Hello, I am 168
# Hello, I am 169
# You can also call me OrderedDict([('x', 3.1459561823076623), ('y', 0.6164433865279744)]), or simply (3.1, 0.62).
# You can also call me OrderedDict([('x', -0.13663159453239793), ('y', -0.2663032113643329)]), or simply (-0.14, -0.27).
# Hello, I am 171
# Hello, I am 170
# MainProcess pypet INFO     PROGRESS: Finished 170/200 runs [=================   ] 85.0%, remaining: 0:00:00
# You can also call me OrderedDict([('x', 0.00653672857140819), ('y', 0.12291215425184188)]), or simply (0.0065, 0.12).
# You can also call me OrderedDict([('x', 4.5340969996159135), ('y', -3.0884528033546443)]), or simply (4.5, -3.1).
# Hello, I am 172
# You can also call me OrderedDict([('x', -4.853385006547574), ('y', 2.293912647914773)]), or simply (-4.9, 2.3).
# Hello, I am 173
# You can also call me OrderedDict([('x', 1.4012113647673843), ('y', -3.5960110765929523)]), or simply (1.4, -3.6).
# Hello, I am 174
# You can also call me OrderedDict([('x', -2.379996204939021), ('y', 3.0132533720246215)]), or simply (-2.4, 3.0).
# Hello, I am 175
# You can also call me OrderedDict([('x', -0.27956270354968993), ('y', -4.8580887832255835)]), or simply (-0.28, -4.9).
# Hello, I am 176
# You can also call me OrderedDict([('x', -2.0099223583375703), ('y', -0.6087435927975218)]), or simply (-2.0, -0.61).
# Hello, I am 177
# You can also call me OrderedDict([('x', -4.356338051665196), ('y', 3.5779057940082666)]), or simply (-4.4, 3.6).
# Hello, I am 178
# You can also call me OrderedDict([('x', -3.9424654524251004), ('y', -4.130764438432703)]), or simply (-3.9, -4.1).
# Hello, I am 179
# You can also call me OrderedDict([('x', 4.018883762896877), ('y', 3.281826866359875)]), or simply (4.0, 3.3).
# Hello, I am 180
# You can also call me OrderedDict([('x', 3.6764051576787473), ('y', 3.1107738475838875)]), or simply (3.7, 3.1).
# MainProcess pypet INFO     PROGRESS: Finished 180/200 runs [==================  ] 90.0%, remaining: 0:00:00
# Hello, I am 181
# You can also call me OrderedDict([('x', -3.404913482686397), ('y', -4.5397867930240885)]), or simply (-3.4, -4.5).
# Hello, I am 182
# You can also call me OrderedDict([('x', -0.786723943709335), ('y', -4.794039829186746)]), or simply (-0.79, -4.8).
# Hello, I am 183
# You can also call me OrderedDict([('x', 3.8576929999406033), ('y', -3.514136399234249)]), or simply (3.9, -3.5).
# Hello, I am 184
# You can also call me OrderedDict([('x', 1.0471917665039143), ('y', -0.7234570001274179)]), or simply (1.0, -0.72).
# Hello, I am 185
# You can also call me OrderedDict([('x', 3.407802889469119), ('y', -1.771643123671903)]), or simply (3.4, -1.8).
# Hello, I am 186
# You can also call me OrderedDict([('x', 1.9359958509037254), ('y', -3.8447320174944153)]), or simply (1.9, -3.8).
# Hello, I am 187
# You can also call me OrderedDict([('x', -3.8315553977359063), ('y', 3.9534002831627593)]), or simply (-3.8, 4.0).
# Hello, I am 188
# You can also call me OrderedDict([('x', -2.2432756591302705), ('y', -1.3294163889173918)]), or simply (-2.2, -1.3).
# Hello, I am 189
# You can also call me OrderedDict([('x', -4.112518891446436), ('y', -2.528178113745936)]), or simply (-4.1, -2.5).
# Hello, I am 190
# You can also call me OrderedDict([('x', 4.738633825063477), ('y', -0.6555774400522978)]), or simply (4.7, -0.66).
# MainProcess pypet INFO     PROGRESS: Finished 190/200 runs [=================== ] 95.0%, remaining: 0:00:00
# Hello, I am 191
# You can also call me OrderedDict([('x', -3.0729811928460524), ('y', -1.029349356824838)]), or simply (-3.1, -1.0).
# Hello, I am 192
# You can also call me OrderedDict([('x', -4.1995409490272495), ('y', 1.9577469121964297)]), or simply (-4.2, 2.0).
# Hello, I am 193
# You can also call me OrderedDict([('x', -1.5283887855721154), ('y', -0.24332822728341785)]), or simply (-1.5, -0.24).
# Hello, I am 194
# You can also call me OrderedDict([('x', -4.186615488837512), ('y', -1.5560923991673525)]), or simply (-4.2, -1.6).
# Hello, I am 195
# You can also call me OrderedDict([('x', 4.466077673290112), ('y', -3.957756276425747)]), or simply (4.5, -4.0).
# Hello, I am 196
# You can also call me OrderedDict([('x', 4.53674628810003), ('y', -1.4253231460804914)]), or simply (4.5, -1.4).
# Hello, I am 197
# You can also call me OrderedDict([('x', 0.362744916446335), ('y', 0.7042705956792723)]), or simply (0.36, 0.7).
# Hello, I am 198
# You can also call me OrderedDict([('x', -4.8245109776050485), ('y', 4.798600396069622)]), or simply (-4.8, 4.8).
# Hello, I am 199
# You can also call me OrderedDict([('x', -2.3136698313945123), ('y', -2.2555579454324572)]), or simply (-2.3, -2.3).
# MainProcess pypet INFO     PROGRESS: Finished 200/200 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-01-31-18H-35M-12S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-01-31-18H-35M-12S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# /Users/caglar/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:4597: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   if (np.issubdtype(val.dtype, str) or
# /Users/caglar/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:4598: FutureWarning: Conversion of the second argument of issubdtype from `bytes` to `bytes` is deprecated. In future, it will be treated as `np.bytes_ == np.dtype(bytes).type`.
#   np.issubdtype(val.dtype, bytes)):
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# /Users/caglar/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess root INFO     Start of evolution
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess root INFO     ----------- Generation 1 -----------
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-01-31-18H-35M-12S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 200/250 runs [================    ] 80.0%
# Hello, I am 200
# Hello, I am 201
# You can also call me OrderedDict([('x', 4.115775353531443), ('y', -4.333080092083689)]), or simply (4.1, -4.3).
# Hello, I am 202
# You can also call me OrderedDict([('x', 2.793437592623735), ('y', -2.890666289523058)]), or simply (2.8, -2.9).
# Hello, I am 203
# You can also call me OrderedDict([('x', -1.2887690078462823), ('y', -3.4842923381281707)]), or simply (-1.3, -3.5).
# You can also call me OrderedDict([('x', -0.8740501302575144), ('y', 0.2755079318061959)]), or simply (-0.87, 0.28).
# Hello, I am 204
# Hello, I am 206
# You can also call me OrderedDict([('x', -0.6742265600438349), ('y', 0.11015110651484111)]), or simply (-0.67, 0.11).
# Hello, I am 205
# You can also call me OrderedDict([('x', 1.9194881742455658), ('y', -0.9601147791112048)]), or simply (1.9, -0.96).
# You can also call me OrderedDict([('x', 2.30780796976991), ('y', -1.6656840207326145)]), or simply (2.3, -1.7).
# Hello, I am 207
# You can also call me OrderedDict([('x', -4.0921285678412875), ('y', -0.043899140823210725)]), or simply (-4.1, -0.044).
# Hello, I am 208
# You can also call me OrderedDict([('x', 1.5168781502946014), ('y', -0.5143875719070334)]), or simply (1.5, -0.51).
# Hello, I am 209
# Hello, I am 210
# You can also call me OrderedDict([('x', 1.032867888174701), ('y', 0.5216957979741532)]), or simply (1.0, 0.52).
# Hello, I am 212
# You can also call me OrderedDict([('x', 0.8416264527177701), ('y', -0.2252222017833559)]), or simply (0.84, -0.23).
# Hello, I am 211
# Hello, I am 213
# You can also call me OrderedDict([('x', -2.0018747502160297), ('y', 1.128302673354137)]), or simply (-2.0, 1.1).
# Hello, I am 214
# Hello, I am 215
# You can also call me OrderedDict([('x', -0.9589586110971233), ('y', 1.9222176715741346)]), or simply (-0.96, 1.9).
# You can also call me OrderedDict([('x', -1.3761245935956816), ('y', 0.1501306198108322)]), or simply (-1.4, 0.15).
# You can also call me OrderedDict([('x', -1.0688444592881894), ('y', -1.2595826101767842)]), or simply (-1.1, -1.3).
# You can also call me OrderedDict([('x', 3.2192802756349757), ('y', 1.8082860693284546)]), or simply (3.2, 1.8).
# MainProcess pypet INFO     PROGRESS: Finished 213/250 runs [=================   ] 85.2%, remaining: 0:00:00
# Hello, I am 216
# You can also call me OrderedDict([('x', -0.03685516226698782), ('y', 4.510485362772454)]), or simply (-0.037, 4.5).
# Hello, I am 217
# Hello, I am 218
# You can also call me OrderedDict([('x', -2.226309546124657), ('y', 1.031571007875126)]), or simply (-2.2, 1.0).
# You can also call me OrderedDict([('x', 0.03729709088090552), ('y', -1.2559839023101187)]), or simply (0.037, -1.3).
# Hello, I am 219
# You can also call me OrderedDict([('x', -1.004789101757146), ('y', -1.0691664921016368)]), or simply (-1.0, -1.1).
# Hello, I am 220
# You can also call me OrderedDict([('x', 1.0552523393332445), ('y', -1.9431437772015157)]), or simply (1.1, -1.9).
# Hello, I am 222
# Hello, I am 221
# Hello, I am 223
# You can also call me OrderedDict([('x', 0.9819772976834319), ('y', 4.759437201767617)]), or simply (0.98, 4.8).
# You can also call me OrderedDict([('x', -4.897264848277168), ('y', 0.019821772967078266)]), or simply (-4.9, 0.02).
# You can also call me OrderedDict([('x', -2.5960311334875676), ('y', -3.166373109340223)]), or simply (-2.6, -3.2).
# Hello, I am 224
# You can also call me OrderedDict([('x', -1.4606552280535716), ('y', -0.4365477227085133)]), or simply (-1.5, -0.44).
# MainProcess pypet INFO     PROGRESS: Finished 225/250 runs [==================  ] 90.0%, remaining: 0:00:00
# Hello, I am 225
# Hello, I am 226
# You can also call me OrderedDict([('x', -0.9738922072679634), ('y', -0.5663371220275271)]), or simply (-0.97, -0.57).
# You can also call me OrderedDict([('x', 0.49472049930812645), ('y', -3.351413828231608)]), or simply (0.49, -3.4).
# Hello, I am 227
# Hello, I am 228
# You can also call me OrderedDict([('x', 3.3993433202355536), ('y', 0.7964802729435772)]), or simply (3.4, 0.8).
# You can also call me OrderedDict([('x', 2.291789004942296), ('y', 0.27935295794000026)]), or simply (2.3, 0.28).
# Hello, I am 229
# You can also call me OrderedDict([('x', 2.2342242774790853), ('y', -0.7376010395522015)]), or simply (2.2, -0.74).
# Hello, I am 230
# You can also call me OrderedDict([('x', -3.1602266968138397), ('y', 4.883992190955366)]), or simply (-3.2, 4.9).
# Hello, I am 231
# You can also call me OrderedDict([('x', 1.3082997688021325), ('y', 1.355717442883177)]), or simply (1.3, 1.4).
# Hello, I am 232
# You can also call me OrderedDict([('x', 1.4336744936100452), ('y', 1.5932568854120115)]), or simply (1.4, 1.6).
# Hello, I am 233
# You can also call me OrderedDict([('x', 2.7625832790719973), ('y', 3.6566196560259456)]), or simply (2.8, 3.7).
# Hello, I am 234
# Hello, I am 235
# You can also call me OrderedDict([('x', -3.727324607795938), ('y', 3.6641517902910685)]), or simply (-3.7, 3.7).
# You can also call me OrderedDict([('x', -1.2818544799284068), ('y', 1.327513907563519)]), or simply (-1.3, 1.3).
# Hello, I am 236
# Hello, I am 237
# You can also call me OrderedDict([('x', -3.4794011794700945), ('y', 0.17669499943195643)]), or simply (-3.5, 0.18).
# You can also call me OrderedDict([('x', -2.713270518293187), ('y', -0.8887942897154786)]), or simply (-2.7, -0.89).
# Hello, I am 238
# You can also call me OrderedDict([('x', -2.1877922858839622), ('y', 1.4688644413493042)]), or simply (-2.2, 1.5).
# Hello, I am 239
# You can also call me OrderedDict([('x', -3.2631731743489336), ('y', -0.6164920237690157)]), or simply (-3.3, -0.62).
# Hello, I am 240
# You can also call me OrderedDict([('x', -0.43086537946166725), ('y', 1.1910438695051808)]), or simply (-0.43, 1.2).
# Hello, I am 241
# You can also call me OrderedDict([('x', -0.9104684670498422), ('y', -1.8443987280082876)]), or simply (-0.91, -1.8).
# MainProcess pypet INFO     PROGRESS: Finished 238/250 runs [=================== ] 95.2%, remaining: 0:00:00
# Hello, I am 242
# You can also call me OrderedDict([('x', 1.4144702388805808), ('y', 0.776782108828942)]), or simply (1.4, 0.78).
# Hello, I am 244
# Hello, I am 243
# You can also call me OrderedDict([('x', -1.2634141487082668), ('y', 0.08678492105338975)]), or simply (-1.3, 0.087).
# You can also call me OrderedDict([('x', -3.013939017882681), ('y', -2.248412984357716)]), or simply (-3.0, -2.2).
# Hello, I am 245
# You can also call me OrderedDict([('x', 1.3107847677192623), ('y', 2.4232840533702307)]), or simply (1.3, 2.4).
# Hello, I am 246
# Hello, I am 247
# You can also call me OrderedDict([('x', 2.742503910991834), ('y', 1.2149762337740129)]), or simply (2.7, 1.2).
# Hello, I am 248
# You can also call me OrderedDict([('x', -1.6558351074406903), ('y', 0.5156556800118599)]), or simply (-1.7, 0.52).
# You can also call me OrderedDict([('x', -1.3753527197450703), ('y', -2.251077827584766)]), or simply (-1.4, -2.3).
# Hello, I am 249
# You can also call me OrderedDict([('x', -2.231681825324411), ('y', 1.5041199834147267)]), or simply (-2.2, 1.5).
# MainProcess pypet INFO     PROGRESS: Finished 250/250 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-01-31-18H-35M-12S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-01-31-18H-35M-12S` were completed successfully.
# MainProcess root INFO     Best individual is [-0.7382070349397187, -0.5592225729590563, 3.3333333333333335, 3.3333333333333335]
# MainProcess root INFO     Score: -0.14232048745856185
# MainProcess root INFO     Fitness: (0.14232048745856185,)
# MainProcess root INFO     --- Population statistics ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess root INFO     ----------- Generation 2 -----------
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-01-31-18H-35M-12S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 250/300 runs [================    ] 83.3%
# Hello, I am 250
# You can also call me OrderedDict([('x', -2.5018920881511297), ('y', -0.48464186230618045)]), or simply (-2.5, -0.48).
# Hello, I am 251
# You can also call me OrderedDict([('x', -2.538810844354676), ('y', -2.844141490676076)]), or simply (-2.5, -2.8).
# Hello, I am 252
# You can also call me OrderedDict([('x', -0.7827940159570674), ('y', -0.4161937646295293)]), or simply (-0.78, -0.42).
# Hello, I am 253
# You can also call me OrderedDict([('x', -0.011799312083336039), ('y', -0.25516572651118996)]), or simply (-0.012, -0.26).
# Hello, I am 254
# You can also call me OrderedDict([('x', 0.04626380507189165), ('y', -0.05666511076048894)]), or simply (0.046, -0.057).
# Hello, I am 255
# You can also call me OrderedDict([('x', 1.1253176935581253), ('y', 3.8570181133011427)]), or simply (1.1, 3.9).
# MainProcess pypet INFO     PROGRESS: Finished 255/300 runs [=================   ] 85.0%, remaining: 0:00:01
# Hello, I am 257
# Hello, I am 256
# You can also call me OrderedDict([('x', -1.0556878346688021), ('y', 0.0434786276394723)]), or simply (-1.1, 0.043).
# You can also call me OrderedDict([('x', 3.226864616399866), ('y', -1.3361191110373987)]), or simply (3.2, -1.3).
# Hello, I am 258
# You can also call me OrderedDict([('x', 0.8840160285292313), ('y', 0.8596646333676989)]), or simply (0.88, 0.86).
# Hello, I am 259
# You can also call me OrderedDict([('x', 4.919004614303656), ('y', -1.5405037868631264)]), or simply (4.9, -1.5).
# Hello, I am 260
# You can also call me OrderedDict([('x', -0.5658183323156263), ('y', 1.0001763037493276)]), or simply (-0.57, 1.0).
# Hello, I am 261
# Hello, I am 263
# You can also call me OrderedDict([('x', -1.2877272416950027), ('y', 0.739376908100931)]), or simply (-1.3, 0.74).
# You can also call me OrderedDict([('x', 2.1280938917201997), ('y', 0.47874011299263725)]), or simply (2.1, 0.48).
# Hello, I am 262
# You can also call me OrderedDict([('x', -1.906647317220993), ('y', 0.8913287067168223)]), or simply (-1.9, 0.89).
# Hello, I am 264
# You can also call me OrderedDict([('x', -0.892769817209347), ('y', -0.981576013814427)]), or simply (-0.89, -0.98).
# Hello, I am 265
# You can also call me OrderedDict([('x', -0.11528098897026506), ('y', -0.8741362386707594)]), or simply (-0.12, -0.87).
# Hello, I am 266
# You can also call me OrderedDict([('x', 2.61736274324424), ('y', -0.07634375070946775)]), or simply (2.6, -0.076).
# Hello, I am 267
# You can also call me OrderedDict([('x', -3.956742555115353), ('y', 2.0347371372460747)]), or simply (-4.0, 2.0).
# Hello, I am 268
# You can also call me OrderedDict([('x', -0.09642987895902766), ('y', -0.352782931728945)]), or simply (-0.096, -0.35).
# Hello, I am 269
# You can also call me OrderedDict([('x', 4.262135601920939), ('y', 1.2624133466038392)]), or simply (4.3, 1.3).
# Hello, I am 270
# You can also call me OrderedDict([('x', -0.2697962297210353), ('y', 2.526356762155021)]), or simply (-0.27, 2.5).
# Hello, I am 271
# You can also call me OrderedDict([('x', -1.903668769956092), ('y', -1.429836195126687)]), or simply (-1.9, -1.4).
# Hello, I am 272
# You can also call me OrderedDict([('x', -1.9709821109966845), ('y', 1.4210241112831477)]), or simply (-2.0, 1.4).
# MainProcess pypet INFO     PROGRESS: Finished 270/300 runs [==================  ] 90.0%, remaining: 0:00:00
# Hello, I am 273
# Hello, I am 274
# You can also call me OrderedDict([('x', 1.923570627235474), ('y', 4.366097448573013)]), or simply (1.9, 4.4).
# You can also call me OrderedDict([('x', 2.565040021346706), ('y', -0.07700030337595098)]), or simply (2.6, -0.077).
# Hello, I am 275
# You can also call me OrderedDict([('x', -0.5358629610999063), ('y', -0.6274184474415156)]), or simply (-0.54, -0.63).
# Hello, I am 276
# You can also call me OrderedDict([('x', 2.8758758481454376), ('y', 3.7814956283096643)]), or simply (2.9, 3.8).
# Hello, I am 277
# Hello, I am 278
# You can also call me OrderedDict([('x', 1.8612015831717554), ('y', 4.065861793015975)]), or simply (1.9, 4.1).
# Hello, I am 279
# You can also call me OrderedDict([('x', 0.9609186450076993), ('y', 2.0128194722355546)]), or simply (0.96, 2.0).
# ...
# Hello, I am 1073
# You can also call me OrderedDict([('x', 0.4985426814639937), ('y', -0.8605940918954709)]), or simply (0.5, -0.86).
# Hello, I am 1072
# You can also call me OrderedDict([('x', -2.7661397605062255), ('y', -0.6637385094051679)]), or simply (-2.8, -0.66).
# You can also call me OrderedDict([('x', 0.9182080095035372), ('y', 0.2298788123178774)]), or simply (0.92, 0.23).
# Hello, I am 1074
# You can also call me OrderedDict([('x', 0.8023970588504724), ('y', -0.5030937578468417)]), or simply (0.8, -0.5).
# Hello, I am 1075
# You can also call me OrderedDict([('x', -0.009103727192138783), ('y', -1.0885576493215106)]), or simply (-0.0091, -1.1).
# Hello, I am 1076
# You can also call me OrderedDict([('x', 0.940743862630344), ('y', 0.30000151853762325)]), or simply (0.94, 0.3).
# Hello, I am 1077
# You can also call me OrderedDict([('x', -0.3973117916769827), ('y', -0.9812608540376693)]), or simply (-0.4, -0.98).
# Hello, I am 1078
# Hello, I am 1080
# You can also call me OrderedDict([('x', -4.7790565710490265), ('y', 2.4127519003064197)]), or simply (-4.8, 2.4).
# You can also call me OrderedDict([('x', 0.6865377359663282), ('y', 0.4391641479726031)]), or simply (0.69, 0.44).
# Hello, I am 1081
# You can also call me OrderedDict([('x', 0.6839643624415489), ('y', 1.1246429768884905)]), or simply (0.68, 1.1).
# Hello, I am 1079
# Hello, I am 1082
# You can also call me OrderedDict([('x', 0.5052546323870474), ('y', -0.6595648624470466)]), or simply (0.51, -0.66).
# Hello, I am 1083
# You can also call me OrderedDict([('x', 0.6316622731361565), ('y', -1.7069636674046875)]), or simply (0.63, -1.7).
# You can also call me OrderedDict([('x', 0.7319306636704072), ('y', -0.42049399632526296)]), or simply (0.73, -0.42).
# Hello, I am 1084
# You can also call me OrderedDict([('x', -0.9062895716530418), ('y', -0.6655713870631215)]), or simply (-0.91, -0.67).
# Hello, I am 1085
# You can also call me OrderedDict([('x', 0.5825794903285659), ('y', -0.8874140948579985)]), or simply (0.58, -0.89).
# Hello, I am 1086
# Hello, I am 1087
# You can also call me OrderedDict([('x', 0.9454908433595803), ('y', 0.07248544079417976)]), or simply (0.95, 0.072).
# You can also call me OrderedDict([('x', -0.5702293177027562), ('y', -1.210088247364152)]), or simply (-0.57, -1.2).
# Hello, I am 1088
# You can also call me OrderedDict([('x', -0.9158225069197516), ('y', -0.5515649393440999)]), or simply (-0.92, -0.55).
# Hello, I am 1089
# You can also call me OrderedDict([('x', -1.3549439562205616), ('y', -0.88262443873031)]), or simply (-1.4, -0.88).
# Hello, I am 1090
# You can also call me OrderedDict([('x', -0.052712395669007914), ('y', -0.8705987495690932)]), or simply (-0.053, -0.87).
# Hello, I am 1091
# You can also call me OrderedDict([('x', 0.6291999930199207), ('y', -0.708659940665131)]), or simply (0.63, -0.71).
# Hello, I am 1092
# You can also call me OrderedDict([('x', 0.30682034596123525), ('y', -0.8334889523590235)]), or simply (0.31, -0.83).
# Hello, I am 1093
# You can also call me OrderedDict([('x', 2.056132956615812), ('y', -1.134906120256858)]), or simply (2.1, -1.1).
# Hello, I am 1094
# You can also call me OrderedDict([('x', 1.0005312798297878), ('y', 0.665234632069446)]), or simply (1.0, 0.67).
# Hello, I am 1095
# You can also call me OrderedDict([('x', -0.21772359120746976), ('y', 0.14411861636226453)]), or simply (-0.22, 0.14).
# Hello, I am 1096
# Hello, I am 1097
# You can also call me OrderedDict([('x', -0.5302230157612852), ('y', -1.0938327508290784)]), or simply (-0.53, -1.1).
# You can also call me OrderedDict([('x', 0.5066035324970193), ('y', -1.0735219608060809)]), or simply (0.51, -1.1).
# Hello, I am 1098
# You can also call me OrderedDict([('x', 0.19782829974123484), ('y', -1.0077795267009328)]), or simply (0.2, -1.0).
# Hello, I am 1099
# You can also call me OrderedDict([('x', 1.2193514379574473), ('y', 0.25192987323869376)]), or simply (1.2, 0.25).
# MainProcess pypet INFO     PROGRESS: Finished 1100/1100 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-01-31-18H-35M-12S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-01-31-18H-35M-12S` were completed successfully.
# MainProcess root INFO     Best individual is [-0.8272949472004326, -0.5653379030104285, 0.29524855317323195, 0.18048699641227706]
# MainProcess root INFO     Score: -0.0040238742435954045
# MainProcess root INFO     Fitness: (0.0040238742435954045,)
# MainProcess root INFO     --- Population statistics ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess root INFO     ----------- Generation 19 -----------
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-01-31-18H-35M-12S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1100/1150 runs [=================== ] 95.7%
# Hello, I am 1100
# Hello, I am 1101
# You can also call me OrderedDict([('x', 0.5740645318237761), ('y', -0.7568912092247223)]), or simply (0.57, -0.76).
# You can also call me OrderedDict([('x', 3.2302339769731714), ('y', 0.2919743934183894)]), or simply (3.2, 0.29).
# Hello, I am 1102
# You can also call me OrderedDict([('x', 1.0460647431366517), ('y', 0.07346066082588029)]), or simply (1.0, 0.073).
# Hello, I am 1103
# Hello, I am 1104
# You can also call me OrderedDict([('x', 0.11962460487327098), ('y', 1.2773373854536887)]), or simply (0.12, 1.3).
# You can also call me OrderedDict([('x', 2.8740533985117134), ('y', 1.0249033444699025)]), or simply (2.9, 1.0).
# Hello, I am 1105
# Hello, I am 1106
# Hello, I am 1107
# You can also call me OrderedDict([('x', 0.23538295116973168), ('y', -2.1554333159210084)]), or simply (0.24, -2.2).
# You can also call me OrderedDict([('x', 0.4247531941925641), ('y', -0.8999569718197626)]), or simply (0.42, -0.9).
# You can also call me OrderedDict([('x', 0.5878090085846722), ('y', -0.8153532834497994)]), or simply (0.59, -0.82).
# Hello, I am 1108
# You can also call me OrderedDict([('x', 0.9066925929318941), ('y', 0.2344703584681227)]), or simply (0.91, 0.23).
# Hello, I am 1109
# You can also call me OrderedDict([('x', 0.8981133092609936), ('y', 0.23618788877261912)]), or simply (0.9, 0.24).
# Hello, I am 1110
# You can also call me OrderedDict([('x', -0.9785078600395546), ('y', -0.6163300950776469)]), or simply (-0.98, -0.62).
# Hello, I am 1112
# You can also call me OrderedDict([('x', 1.0402560200968995), ('y', 0.008185666346944565)]), or simply (1.0, 0.0082).
# Hello, I am 1111
# You can also call me OrderedDict([('x', 0.6552948239311467), ('y', 0.2606396788746806)]), or simply (0.66, 0.26).
# Hello, I am 1113
# Hello, I am 1114
# You can also call me OrderedDict([('x', -0.36313506246495336), ('y', -1.6204095880793574)]), or simply (-0.36, -1.6).
# Hello, I am 1115
# You can also call me OrderedDict([('x', -0.4544352393489588), ('y', -0.821875712716453)]), or simply (-0.45, -0.82).
# You can also call me OrderedDict([('x', 0.9889183320661722), ('y', 0.23261903543943183)]), or simply (0.99, 0.23).
# Hello, I am 1116
# You can also call me OrderedDict([('x', 0.4439184454898214), ('y', -0.3672963323220872)]), or simply (0.44, -0.37).
# Hello, I am 1117
# You can also call me OrderedDict([('x', 1.0752342198355178), ('y', 0.275057993193899)]), or simply (1.1, 0.28).
# Hello, I am 1118
# You can also call me OrderedDict([('x', 2.6477280738779543), ('y', -3.6744854926366015)]), or simply (2.6, -3.7).
# Hello, I am 1119
# Hello, I am 1120
# You can also call me OrderedDict([('x', -0.33344863253601065), ('y', 0.9431342282466135)]), or simply (-0.33, 0.94).
# You can also call me OrderedDict([('x', 0.3717247032972624), ('y', 4.404892352734492)]), or simply (0.37, 4.4).
# Hello, I am 1121
# You can also call me OrderedDict([('x', 0.7717206137581893), ('y', -0.5165947769214557)]), or simply (0.77, -0.52).
# Hello, I am 1122
# You can also call me OrderedDict([('x', 1.0365215643137051), ('y', -0.7563075842081421)]), or simply (1.0, -0.76).
# Hello, I am 1123
# You can also call me OrderedDict([('x', 0.5467977917991874), ('y', 0.43356197929876444)]), or simply (0.55, 0.43).
# Hello, I am 1124
# You can also call me OrderedDict([('x', -0.3905331908243943), ('y', 0.019108612077435028)]), or simply (-0.39, 0.019).
# Hello, I am 1125
# You can also call me OrderedDict([('x', -3.244107817977873), ('y', -2.1682240364668117)]), or simply (-3.2, -2.2).
# Hello, I am 1126
# You can also call me OrderedDict([('x', 0.6251045407260905), ('y', -0.7694493712062132)]), or simply (0.63, -0.77).
# Hello, I am 1127
# Hello, I am 1128
# You can also call me OrderedDict([('x', -0.20464964283603676), ('y', -0.7938756038332511)]), or simply (-0.2, -0.79).
# Hello, I am 1129
# You can also call me OrderedDict([('x', 1.5640314516823395), ('y', -0.7975574779768008)]), or simply (1.6, -0.8).
# You can also call me OrderedDict([('x', 0.7404120951688734), ('y', -0.7693085980175218)]), or simply (0.74, -0.77).
# Hello, I am 1130
# You can also call me OrderedDict([('x', 0.9650241402210816), ('y', -1.119380736311079)]), or simply (0.97, -1.1).
# Hello, I am 1131
# Hello, I am 1132
# You can also call me OrderedDict([('x', 1.5077827972552669), ('y', -1.0723281395611937)]), or simply (1.5, -1.1).
# You can also call me OrderedDict([('x', 2.0469499544199374), ('y', 1.623316859662326)]), or simply (2.0, 1.6).
# Hello, I am 1133
# You can also call me OrderedDict([('x', 1.2373169511237592), ('y', -0.060658731178503955)]), or simply (1.2, -0.061).
# Hello, I am 1134
# You can also call me OrderedDict([('x', 0.8667092341877547), ('y', -1.0223736266662118)]), or simply (0.87, -1.0).
# Hello, I am 1136
# Hello, I am 1135
# Hello, I am 1137
# You can also call me OrderedDict([('x', 1.0083881044844776), ('y', -0.04162115743332326)]), or simply (1.0, -0.042).
# You can also call me OrderedDict([('x', -0.8058613148610492), ('y', -0.7055649882606707)]), or simply (-0.81, -0.71).
# You can also call me OrderedDict([('x', 0.8420503688518226), ('y', -1.477151080110682)]), or simply (0.84, -1.5).
# Hello, I am 1138
# You can also call me OrderedDict([('x', 0.19548766811586005), ('y', 1.4671218331841855)]), or simply (0.2, 1.5).
# Hello, I am 1139
# You can also call me OrderedDict([('x', 1.0128135200119488), ('y', 0.5414137066495257)]), or simply (1.0, 0.54).
# Hello, I am 1140
# Hello, I am 1141
# You can also call me OrderedDict([('x', 0.74252633397735), ('y', -0.09144284457820956)]), or simply (0.74, -0.091).
# You can also call me OrderedDict([('x', 3.790563580689131), ('y', 0.2254730646566535)]), or simply (3.8, 0.23).
# Hello, I am 1142
# You can also call me OrderedDict([('x', 0.6755069951335068), ('y', 0.7041068696021928)]), or simply (0.68, 0.7).
# Hello, I am 1143
# You can also call me OrderedDict([('x', 0.5453171661990531), ('y', 0.8378654219006889)]), or simply (0.55, 0.84).
# Hello, I am 1144
# You can also call me OrderedDict([('x', 0.8575806529406642), ('y', -0.7564017066152607)]), or simply (0.86, -0.76).
# Hello, I am 1145
# You can also call me OrderedDict([('x', -0.0015773914161764796), ('y', -1.1626366274928082)]), or simply (-0.0016, -1.2).
# Hello, I am 1146
# You can also call me OrderedDict([('x', -0.4776096411884126), ('y', -0.5544721711029107)]), or simply (-0.48, -0.55).
# Hello, I am 1147
# You can also call me OrderedDict([('x', 0.7246377190819902), ('y', -0.9583462030094407)]), or simply (0.72, -0.96).
# Hello, I am 1148
# You can also call me OrderedDict([('x', 1.7868254394164338), ('y', -1.1440342428077304)]), or simply (1.8, -1.1).
# Hello, I am 1149
# You can also call me OrderedDict([('x', -0.058048622318817356), ('y', -1.962910377327047)]), or simply (-0.058, -2.0).
# MainProcess pypet INFO     PROGRESS: Finished 1150/1150 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-01-31-18H-35M-12S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-01-31-18H-35M-12S` were completed successfully.
# MainProcess root INFO     Best individual is [0.5453171661990531, 0.8378654219006889, 0.04589371824306831, 2.0154592311531774]
# MainProcess root INFO     Score: -0.0006107230318148638
# MainProcess root INFO     Fitness: (0.0006107230318148638,)
# MainProcess root INFO     --- Population statistics ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess root INFO     --- End of evolution ---
# MainProcess root INFO     Best individual is [0.5453171661990531, 0.8378654219006889, 0.04589371824306831, 2.0154592311531774], (0.0006107230318148638,)
# MainProcess root INFO     --- End of evolution ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-01-31-18H-35M-12S`.

# %%
traj = evolution.loadResults()
# Out:
# MainProcess root INFO     Loading results from ./data/hdf/evolution.hdf
# MainProcess root INFO     Analyzing trajectory results-2020-01-31-18H-35M-12S
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `./data/hdf/evolution.hdf`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading trajectory `results-2020-01-31-18H-35M-12S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `config` in mode `2`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `derived_parameters` in mode `1`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `parameters` in mode `2`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `results` in mode `1`.

# %%
evolution.info(plot=True)
# Out:
# Parameters dictribution (Generation 19):
# x: 	 mean: 0.4356,	 std: 0.5944
# y: 	 mean: -0.271,	 std: 0.6225
# There are 50 valid individuals
# Mean score across population: -0.033
# Printing 20 individuals
# Individual 0 pars x 0.5453, y 0.8379
# 	Fitness values:  0.0006
# Individual 1 pars x -0.3334, y 0.9431
# 	Fitness values:  0.0007
# Individual 2 pars x -0.8273, y -0.5653
# 	Fitness values:  0.004
# Individual 3 pars x 0.9342, y 0.3639
# 	Fitness values:  0.0051
# Individual 4 pars x -0.2982, y -0.9518
# 	Fitness values:  0.0052
# Individual 5 pars x 0.9041, y 0.4164
# 	Fitness values:  0.0093
# Individual 6 pars x 0.4248, y -0.9
# 	Fitness values:  0.0097
# Individual 7 pars x 0.6494, y -0.7539
# 	Fitness values:  0.01
# Individual 8 pars x 0.5878, y -0.8154
# 	Fitness values:  0.0103
# Individual 9 pars x 0.4985, y -0.8606
# 	Fitness values:  0.0108
# Individual 10 pars x 0.767, y -0.6502
# 	Fitness values:  0.011
# Individual 11 pars x 0.562, y -0.8204
# 	Fitness values:  0.0111
# Individual 12 pars x 0.9732, y 0.2598
# 	Fitness values:  0.0147
# Individual 13 pars x 0.6251, y -0.7694
# 	Fitness values:  0.0172
# Individual 14 pars x 1.008, y -0.04162
# 	Fitness values:  0.0186
# Individual 15 pars x 0.5707, y -0.8338
# 	Fitness values:  0.021
# Individual 16 pars x 1.004, y 0.1118
# 	Fitness values:  0.0212
# Individual 17 pars x -0.2396, y -0.9834
# 	Fitness values:  0.0245
# Individual 18 pars x 0.8099, y 0.6074
# 	Fitness values:  0.0249
# Individual 19 pars x 0.9407, y 0.3
# 	Fitness values:  0.025

# %%
gens, all_scores = evolution.getScoresDuringEvolution()

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4), dpi=200)   
plt.plot(gens, np.nanmean(all_scores, axis=1))
plt.fill_between(gens, np.nanmin(all_scores, axis=1), np.nanmax(all_scores, axis=1), alpha=0.3)
plt.xlabel("Generation #")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')
